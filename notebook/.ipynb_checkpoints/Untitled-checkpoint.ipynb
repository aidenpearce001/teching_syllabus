# %% [markdown]
# <h1> Cài đặt MongoDB </h1>

# %% [markdown]
# Vào trang chủ của mongdb để tải hoặc bấm vào <a href="https://www.mongodb.com/download-center/community">link</a>
# OS lựa chọn hệ điều hành để cài đặt, ở đây ta chọn Windows 64-bits
# Package định dạng file tải về , cho windows thì MSI hoặc ZIP(Linux sẽ có tar.gz , zip ,...)

# %%
from IPython.display import Image
Image("../img/1.png", width="700", height="700")

# %% [markdown]
# Sau khi down xong bấm vào file vừa tải

# %%
Image("../img/2.png", width="600", height="600")

# %%
Image("../img/3.png", width="500", height="500")

# %%
Image("../img/4.png", width="600", height="600")

# %%
Image("../img/5.png", width="500", height="500")

# %%
Image("../img/6.png", width="700", height="700")

# %%
Chúng ta k cần MongDB compass nên bỏ tick

# %%
Image("../img/7.png", width="600", height="600")

# %%
Image("../img/8.png", width="500", height="500")

# %% [markdown]
# OK , vậy là ta đã cài xong rồi
# <br>Giờ chạy sao ???

# %% [markdown]
# Cách 1 vào đường dẫn C:\Program Files\MongoDB\Server\4.2\bin và chạy mongo.exe
# <br>2 là vào cmd và gõ "C:\Program Files\MongoDB\Server\4.2\bin\mongo.exe"

# %%
Image("../img/9.png", width="700", height="700")

# %% [markdown]
# Vậy lúc nào ra muốn chạy mongo cũng phải làm mấy trò con bò này à ?
# <br>Để vào nhanh hơn chỉ với 1 lệnh ta làm các bước sau
# <br><b>Control Panel>System and Security>System>Advanced System Setting</b>

# %%
Image("../img/10.png", width="500", height="500")

# %%
Image("../img/11.png", width="600", height="600")

# %% [markdown]
# Double click vào path > new và nhập path dẫn đến mongo : C:\Program Files\MongoDB\Server\4.2\bin

# %%
Image("../img/12.png", width="500", height="500")

# %% [markdown]
# Bây giờ vào cmd và gõ cmd ! WALLA !

# %%
Image("../img/13.png", width="600", height="600")

# %%
Image("../img/14.png", width="300", height="300")

# %% [markdown]
# <h2>MongoDB CRUD Operations</h2>

# %%
import pymongo 
mongo_url = "mongodb://localhost:27017/"  
client = pymongo.MongoClient(mongo_url)

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local']

# %% [markdown]
# <h5>Tạo collections và insert document vào collections(Create)

# %%
database = client[ "test_database" ]
client.list_database_names()
# Out:
# ['admin', 'config', 'local']

# %%
database = client[ "test_database" ]
my_collection = database[ "my_collection" ]
result=my_collection.insert_one({"car" : "BMW"})
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'test_database']

# %%
mycol = my_collection = database[ "my_collection" ]
car = { 'name': 'Mercedes', 'price': 57127 }

x = mycol.insert_one(mydict)

print(x.inserted_id)
# Out:
# 5ecb53cf7294397ad1e23d3b

# %%
cars = [ {'name': 'Audi', 'price': 52642},
    {'name': 'Mercedes', 'price': 57127},
    {'name': 'Skoda', 'price': 9000},
    {'name': 'Volvo', 'price': 29000},
    {'name': 'Bentley', 'price': 350000},
    {'name': 'Citroen', 'price': 21000},
    {'name': 'Hummer', 'price': 41400},
    {'name': 'Volkswagen', 'price': 21600} ]

x = mycol.insert_many(cars)

#print list of the _id values of the inserted documents:
print(x.inserted_ids)
# Out:
# [ObjectId('5ecb53de7294397ad1e23d3c'), ObjectId('5ecb53de7294397ad1e23d3d'), ObjectId('5ecb53de7294397ad1e23d3e'), ObjectId('5ecb53de7294397ad1e23d3f'), ObjectId('5ecb53de7294397ad1e23d40'), ObjectId('5ecb53de7294397ad1e23d41'), ObjectId('5ecb53de7294397ad1e23d42'), ObjectId('5ecb53de7294397ad1e23d43'), ObjectId('5ecb53de7294397ad1e23d44'), ObjectId('5ecb53de7294397ad1e23d45'), ObjectId('5ecb53de7294397ad1e23d46'), ObjectId('5ecb53de7294397ad1e23d47')]

# %%
cars = [ {'name': 'Audi', 'price': 52642},
    {'name': 'Mercedes', 'price': 57127},
    {'name': 'Skoda', 'price': 9000},
    {'name': 'Volvo', 'price': 29000},
    {'name': 'Bentley', 'price': 350000},
    {'name': 'Citroen', 'price': 21000},
    {'name': 'Hummer', 'price': 41400},
    {'name': 'Volkswagen', 'price': 21600} ]

x = mycol.insert_many(mylist)

#print list of the _id values of the inserted documents:
print(x.inserted_ids)
